# %% [markdown]
# <a href="https://colab.research.google.com/github/DaramG-star/coding-test/blob/main/%EC%9D%B4%EC%B7%A8%ED%8C%8C%5B%EA%B5%AC%ED%98%84%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 완전탐색
# 모든 경우의 수를 주저 없이 다 계산하는 해결 방법
#
# ## 시뮬레이션
# 문제에서 제시한 알고리즘을 한 단계씩 차례대로 직접 수행
#
# ###**두 유형 모두 구현이 핵심!**

# %% [markdown]
# ## 상하좌우
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# 내 풀이
N = int(input())
arr = list(input().split())

x, y = 1, 1

for i in range(len(arr)):
    if arr[i] == 'L':
        if 1 < y:
            y-= 1
    elif arr[i] == 'R':
        if y < N:
            y += 1
    elif arr[i] == 'U':
        if 1 < x:
            x -= 1
    elif arr[i] == 'D':
        if x < N:
            x += 1

print(x, y)

# %%
# 책 풀이
N = int(input())
x, y = 1, 1
plans = input().split()

dx = [0, 0, -1, 1]
dy = [-1, 1, 0, 0]
move_types = ['L', 'R', 'U', 'D']

for plan in plans:
    for d in range(4):
        if plan == move_types[d]:
            nx = x + dx[d]
            ny = y + dy[d]

    if 1 <= nx <= N and 1 <= ny <= N:
        x, y = nx, ny

print(x, y)

# %% [markdown]
# ## 시각
# ![image.png](data:image/png;base64,...)

# %%
#내 풀이 & 책 풀이
def intime(N):
    count = 0
    for i in range(N+1):
        for j in range(60):
            for k in range(60):
                if '3' in str(i) + str(j) + str(k):
                    count += 1
    return count

N = int(input())
result = intime(N)
print(result)

# %% [markdown]
# ## 왕실의 나이트
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# 내 코드
arr = list(input())
x = int(arr[1])
y = ord(arr[0]) - 96
total = 0

# 오른쪽/왼쪽 2칸 이동 후 아래/위
if x >= 3 and y >= 2: # 왼쪽, 위
    total += 1
if x >= 3 and y <= 7: # 왼쪽, 아래
    total += 1

if x <= 6 and y >= 2:
    total += 1
if x <= 6 and y <= 7:
    total += 1

# 아래/위 2칸 이동 후 오른쪽/왼쪽
if y >= 3 and x >= 2:
    total += 1
if y >= 3 and x <= 7:
    total += 1

if y <= 6 and x >= 2:
    total += 1
if y <= 6 and x <= 7:
    total += 1

print(total)
# Out:
# a1
# 2

# %%
# 책 코드
input_data = input()
row = int(input_data[1])
column = int(ord(input_data[0])) - int(ord('a')) + 1

# 나이트가 이동할 수 있는 8가지 방향 정의
steps = [(-2, -1), (-1, -2), (1, -2), (2, -1), (2, 1), (1, 2), (-1, 2), (-2, 1)]

result = 0
for step in steps:
    # 이동하고자 하는 위치 확인
    next_row = row +step[0]
    next_column = column + step[1]

    if 1 <= next_row <= 8 and 1 <= next_column <= 8:
        result += 1

print(result)
# Out:
# a1
# 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
